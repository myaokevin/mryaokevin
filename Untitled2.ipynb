# %% [markdown]
# <a href="https://colab.research.google.com/github/myaokevin/mryaokevin/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
from PIL import Image
from PIL.ExifTags import TAGS
import numpy as np
from google.colab import drive
drive.mount('/content/gdrive/', force_remount=True)
# Out:
# Mounted at /content/gdrive/

# %%
img1 = plt.imread('/content/gdrive/MyDrive/UQAM/Cours/INF889G/data/d1_ex1_im1.jpg')
img2 = plt.imread('/content/gdrive/MyDrive/UQAM/Cours/INF889G/data/d1_ex1_im2.jpg')
img3 = plt.imread('/content/gdrive/MyDrive/UQAM/Cours/INF889G/data/d1_ex1_im3.jpg')
img4 = plt.imread('/content/gdrive/MyDrive/UQAM/Cours/INF889G/data/d1_ex1_im4.jpg')

image = np.array(img1)
#plt.imshow(image)

image = Image.open('/content/gdrive/MyDrive/UQAM/Cours/INF889G/data/d1_ex1_im1.jpg')
# extracting the exif metadata
exifdata = image.getexif()
# looping through all the tags present in exifdata
for tagid in exifdata:
    # getting the tag name instead of tag id
    tagname = TAGS.get(tagid, tagid)
# passing the tagid to get its respective value
    value = exifdata.get(tagid)
# printing the final result
    print(f"{tagname:25}: {value}")

# %%
red_px = np.histogram(red_pixels, bins=256, range=[0, 1])
green_px = np.histogram(green_pixels, bins=256, range=[0, 1])
blue_px = np.histogram(blue_pixels, bins=256, range=[0, 1])

plt.figure(figsize=(8, 6))
plt.plot(red_px[1][:256], red_px[0], color='r')
plt.plot(green_px[1][:256], green_px[0], color='g')
plt.plot(blue_px[1][:256], blue_px[0], color='b')
plt.xticks(ticks=np.linspace(0, 1, 17), labels=range(0, 257, 16))
plt.yscale('log')
plt.show()

# %%
plt.figure(figsize=(12, 12))
#plt.hist(red_pixels, bins=256, density=False, color='red', alpha=0.5)
#plt.hist(green_pixels, bins=256, density=False, color='green', alpha=0.4)
plt.hist(blue_pixels, bins=256, density=False, color='blue', alpha=0.3)

# set labels and ticks
plt.xticks(ticks=np.linspace(0, 1, 50), labels=range(0, 257, 16))

# Cosmetics
plt.title('Histograms from color image')
plt.ylabel('Counts')
plt.xlabel('Intensity')

# Display the plot
plt.show()
